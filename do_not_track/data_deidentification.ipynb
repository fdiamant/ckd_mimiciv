# %%
import pandas as pd
import hashlib

# %%
# Read the CSV files
patients = pd.read_csv("patients_age_flags.csv", delimiter=";")
lab = pd.read_csv("cbc_chem.csv", delimiter=";")

# %%
# Merge the two files on subject_id and hadm_id
temp_df = pd.merge(lab, patients, on=["subject_id", "hadm_id"], how="left")

# %%
# Set the subset to use for deidentification
subset = ["subject_id", "hadm_id", "charttime"]

# Convert the relevant columns astype string 
temp_df[subset] = temp_df[subset].astype(str)

# Extract the relevant columns
subject_id = temp_df["subject_id"]
hadm_id = temp_df["hadm_id"]
charttime = temp_df["charttime"]

# Combine columns to create a hash value
combined_cols = subject_id + hadm_id + charttime

# Apply SHA-256 hash function to create the index
index = combined_cols.apply(lambda x: hashlib.sha256(x.encode()).hexdigest())

# Set the index of the DataFrame
temp_df.set_index(index, inplace=True)

# %%
# Drop unnecessary columns and sort by index
df = temp_df.drop(columns=["subject_id", "hadm_id", "specimen_id", "charttime"]).sort_index()

# %%
# Convert 'age' column to integer data type
df['age'] = df['age'].astype(int)

# %%
# Export the de-identified DataFrame to a new CSV file
df.to_csv("ckd_deidentified.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1636315 entries, 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd9531479e383b8844b to fffff04f91d9bb69086b462eed519b73e03567d768e873746fe6c101e48f1fec
# Data columns (total 26 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   hematocrit     1629960 non-null  float64
#  1   hemoglobin     1593606 non-null  float64
#  2   mch            1588370 non-null  float64
#  3   mchc           1588542 non-null  float64
#  4   mcv            1588470 non-null  float64
#  5   platelet       1598386 non-null  float64
#  6   rbc            1588481 non-null  float64
#  7   rdw            1587352 non-null  float64
#  8   wbc            1590141 non-null  float64
#  9   albumin        257170 non-null   float64
#  10  globulin       7655 non-null     float64
#  11  total_protein  13247 non-null    float64
#  12  aniongap       1580546 non-null  float64
#  13  bicarbonate    1583570 non-null  float64
#  14  bun            1598277 non-null  float64
#  15  calcium        1372546 non-null  float64
#  16  chloride       1602819 non-null  float64
#  17  creatinine     1607316 non-null  float64
#  18  glucose        1567033 non-null  float64
#  19  sodium         1602243 non-null  float64
#  20  potassium      1614938 non-null  float64
#  21  age            1636315 non-null  int64
#  22  gender         1636315 non-null  object
#  23  ckd            1636315 non-null  int64
#  24  hypertension   1636315 non-null  int64
#  25  diabetes       1636315 non-null  int64
# dtypes: float64(21), int64(4), object(1)
# memory usage: 337.1+ MB

# %%
df
# Out:
#                                                     hematocrit  hemoglobin
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...        25.3         8.5  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...        28.6        10.0
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...        31.7        10.1
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...        37.8        12.4
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...        23.1         7.8
# ...                                                        ...         ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...        23.7         7.8
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...        38.3        12.7
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...        32.6        10.1
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...        38.4        12.8
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...        25.3         8.7
#
#                                                      mch  mchc    mcv
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...  28.6  33.4   86.0  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...  29.8  34.9   85.0
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...  28.2  31.9   88.0
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...  31.1  32.9   95.0
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...  28.7  33.7   85.0
# ...                                                  ...   ...    ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...  33.3  32.9  101.0
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...  33.3  33.2  100.0
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...  28.7  31.0   93.0
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...  31.4  33.3   94.0
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...  29.8  34.4   87.0
#
#                                                     platelet   rbc   rdw
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...     275.0  2.96  13.4  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...     102.0  3.36  13.8
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...     201.0  3.58  14.5
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...     347.0  4.00  13.8
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...      76.0  2.71  16.4
# ...                                                      ...   ...   ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...     169.0  2.34  14.4
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...     179.0  3.82  13.1
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...     254.0  3.52  13.4
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...     180.0  4.08  14.6
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...     208.0  2.92  13.6
#
#                                                      wbc  albumin  ...
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...   3.0      NaN  ...  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...   1.9      NaN  ...
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...   4.2      NaN  ...
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...  11.2      3.9  ...
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...   7.8      NaN  ...
# ...                                                  ...      ...  ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...  23.3      NaN  ...
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...  12.6      NaN  ...
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...   7.6      NaN  ...
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...   8.0      NaN  ...
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...  12.4      NaN  ...
#
#                                                     chloride  creatinine
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...     109.0         0.7  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...     104.0         0.7
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...     104.0         0.6
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...     101.0         0.9
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...     105.0         1.5
# ...                                                      ...         ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...      94.0         7.2
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...      99.0         0.7
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...      99.0         0.6
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...     104.0         1.1
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...     108.0         0.6
#
#                                                     glucose  sodium
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...    114.0   140.0  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...     82.0   139.0
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...     97.0   139.0
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...    149.0   139.0
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...    207.0   136.0
# ...                                                     ...     ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...    143.0   133.0
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...    121.0   136.0
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...     97.0   137.0
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...     92.0   142.0
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...    113.0   140.0
#
#                                                     potassium  age  gender
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...        3.9   48       F  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...        3.9   59       M
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...        3.6   83       F
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...        4.1   51       F
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...        4.8   71       M
# ...                                                       ...  ...     ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...        4.3   81       M
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...        3.0   82       M
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...        3.8   74       F
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...        4.0   74       M
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...        3.9   78       F
#
#                                                     ckd  hypertension
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...    0             0  \
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...    0             1
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...    0             1
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...    0             0
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...    1             1
# ...                                                 ...           ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...    1             1
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...    0             1
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...    0             1
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...    0             1
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...    0             1
#
#                                                     diabetes
# 0000003c42d42886f0512786c8cef89336c3dbc4a25e5dd...         0
# 00000727efa061858c1e6611657af5b6defd0ab071091a0...         0
# 00002d1472769d21c156977f93e2e1db0557807f470e08a...         0
# 00004622a4c6b7bb6b873558488dd2e828dc77a5d9587f6...         0
# 00004741d15bcf0f0453f94cdd9eeb85c663584f26c5fe0...         0
# ...                                                      ...
# ffffbc4b10d69e134494f554c6d11aa5c7b3d62a3ed9f27...         1
# ffffcd111a56292182022764fb3047749d3f2aa3fd4801e...         0
# ffffd3c4b674a4b05cd88da299e9955366949066dad07cc...         0
# ffffd3e90e8f8f17ca53a0fd689e5fa276d7b14f088b2b3...         1
# fffff04f91d9bb69086b462eed519b73e03567d768e8737...         0
#
# [1636315 rows x 26 columns]
